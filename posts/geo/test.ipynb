# %%
import matplotlib.pyplot as plt
import numpy as np

# Time period: 2015-2024, 4 points per year (quarterly data)
years = np.arange(2015, 2025, 0.25)

# Synthetic (but realistic) quarterly average exchange rates for the period
# USD/EUR (Quarterly averages based on historical trends)
usd_eur = [
    0.89, 0.91, 0.92, 0.93,
    0.91, 0.90, 0.89, 0.88,
    0.87, 0.86, 0.85, 0.84,
    0.85, 0.86, 0.87, 0.88,
    0.89, 0.90, 0.89, 0.88,
    0.87, 0.86, 0.85, 0.84,
    0.83, 0.84, 0.85, 0.86,
    0.87, 0.88, 0.89, 0.90,
    0.91, 0.92, 0.93, 0.94,
    0.95, 0.94, 0.93, 0.92
]

# EUR/CHF (Quarterly averages)
eur_chf = [
    1.06, 1.07, 1.08, 1.09,
    1.10, 1.11, 1.12, 1.13,
    1.12, 1.11, 1.10, 1.09,
    1.08, 1.07, 1.06, 1.05,
    1.04, 1.03, 1.04, 1.05,
    1.06, 1.07, 1.08, 1.09,
    1.08, 1.07, 1.06, 1.05,
    1.04, 1.03, 1.02, 1.01,
    1.00, 0.99, 0.98, 0.97,
    0.96, 0.97, 0.98, 0.99
]

# EUR/GBP (Quarterly averages)
eur_gbp = [
    0.74, 0.75, 0.76, 0.77,
    0.78, 0.77, 0.76, 0.75,
    0.74, 0.73, 0.72, 0.71,
    0.72, 0.73, 0.74, 0.75,
    0.76, 0.77, 0.76, 0.75,
    0.74, 0.73, 0.72, 0.71,
    0.70, 0.71, 0.72, 0.73,
    0.74, 0.75, 0.76, 0.77,
    0.78, 0.79, 0.80, 0.81,
    0.80, 0.79, 0.78, 0.77
]

# USD/CNY (Quarterly averages)
usd_cny = [
    6.2, 6.3, 6.4, 6.5,
    6.6, 6.7, 6.8, 6.9,
    6.8, 6.7, 6.6, 6.5,
    6.4, 6.3, 6.2, 6.1,
    6.0, 5.9, 6.0, 6.1,
    6.2, 6.3, 6.4, 6.5,
    6.6, 6.7, 6.8, 6.9,
    7.0, 7.1, 7.2, 7.3,
    7.2, 7.1, 7.0, 6.9,
    6.8, 6.7, 6.6, 6.5
]

# Plot USD/EUR vs EUR/CHF
plt.figure(figsize=(12, 8))
plt.subplot(3, 1, 1)
plt.scatter(usd_eur, eur_chf, c=years, cmap='viridis', edgecolor='k', s=50)
plt.colorbar(label='Year')
plt.xlabel('USD/EUR exchange rate')
plt.ylabel('EUR/CHF exchange rate')
plt.title('USD/EUR vs EUR/CHF (2015-2024)')
plt.grid(True)

# Plot USD/EUR vs EUR/GBP
plt.subplot(3, 1, 2)
plt.scatter(usd_eur, eur_gbp, c=years, cmap='plasma', edgecolor='k', s=50)
plt.colorbar(label='Year')
plt.xlabel('USD/EUR exchange rate')
plt.ylabel('EUR/GBP exchange rate')
plt.title('USD/EUR vs EUR/GBP (2015-2024)')
plt.grid(True)

# Plot USD/EUR vs USD/CNY
plt.subplot(3, 1, 3)
plt.scatter(usd_eur, usd_cny, c=years, cmap='cividis', edgecolor='k', s=50)
plt.colorbar(label='Year')
plt.xlabel('USD/EUR exchange rate')
plt.ylabel('USD/CNY exchange rate')
plt.title('USD/EUR vs USD/CNY (2015-2024)')
plt.grid(True)

plt.tight_layout()
plt.show()
